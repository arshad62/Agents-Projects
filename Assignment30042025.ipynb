# %% [markdown]
# <a href="https://colab.research.google.com/github/arshad62/Agents-Projects/blob/main/Assignment30042025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -Uq openai-agents
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.9/116.9 kB 4.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.3/129.3 kB 5.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.1/76.1 kB 4.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 2.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 3.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 kB 3.8 MB/s eta 0:00:00

# %%
import nest_asyncio
nest_asyncio.apply()

# %%
import os
from agents import Agent, Runner, AsyncOpenAI, OpenAIChatCompletionsModel, set_default_openai_client, set_tracing_disabled, set_default_openai_api
from agents.run import RunConfig
from google.colab import userdata


gemini_api_key = userdata.get("GEMINI_API_KEY")

#Reference: https://ai.google.dev/gemini-api/docs/openai
external_client = AsyncOpenAI(
    api_key=gemini_api_key,
    base_url="https://generativelanguage.googleapis.com/v1beta/openai/",
)
set_default_openai_client(external_client)
set_default_openai_api("chat_completions")
set_tracing_disabled(True)

model = OpenAIChatCompletionsModel(
    model="gemini-2.0-flash",
    openai_client=external_client
)

config = RunConfig(
    model=model,
    model_provider=external_client,
    tracing_disabled=True
)

# %%
import asyncio
from agents import Agent, handoff, Runner

# %%
from agents.tool import function_tool

# %%
web_agent = Agent(
    name="Web agent",
    instructions="You are web agent, development of web pages codes"
)

mobile_agent = Agent(
    name="Mobile agent",
    instructions="You are mobile App development agent, you can develop mobile App codes"
)

agenticAI_agent = Agent(
    name="AgenticAI agent",
    instructions="You are Agentic AI agent, you can develop Agentic AI App codes"
)

panacloud_agent = Agent(
    name="Panacloud agent",
    instructions="Handoff to the appropriate agent based on the language of the request.",
    handoffs=[web_agent, mobile_agent, agenticAI_agent],
)

@function_tool("dev_ops")
def dev_ops = Agent(
    name="dev_ops agent",
    instructions="You are mobile App development agent, you can develop mobile App codes"
)







async def main(input: str):
    result = await Runner.run(panacloud_agent, input=input, run_config=config)
    print(result.final_output)
